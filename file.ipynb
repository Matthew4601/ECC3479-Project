# %% [markdown]
# Robustness checks

# %%
run run_robustness.py

# %% [markdown]
# Robustness test 1.
# Tetsing for serially correlation.
# Tests regressions one and three.
# The regressions were rerun with HAC standard erros instead of the HC3 one present in the initial regression to see if there is serial corraltion present and therefore if anything that was stated as initially significant is in fact not.
# After perfroming this test it shows that all three countries pass-through coeffeicents remain significant at the 1% level. The strucutural break, however, only remains significant for the United Kingdom and Canada, the United States strucutural shift was not robust to autocorreltion.

# %% [markdown]
# Robustness test 2.
# Testing for spruious regressions and if the data is stattionary.
# tests regressions one, three, five and six.
# This checks the regressions for a spurious regression through checking if the means are fixed (stationary).
# Five of the six series are non-stationary, with only the USA Energy variable being statioanry. This is shows that the coeffcients in these regressions could potetnilly be spuro=ious and should be interpreted as a long-run co-trending relationship rather than short-run causal.

# %% [markdown]
# Robustness test 3
# Alternative strucutrual break
# tets ression three.
# Uses a different date for the strucutural break to test whether the direction and significance oof teh delta term is consistnt for each nation. Canada and the United Kingdom are both robust and significant at the 1% level, regardelss of teh date used (which ranged betwen AMrch 2020 and July 2022). The United States is not significant across any of the four dates. Tjsi shows that for the United Kingdom adn Canada this is a braod phenomenom and not a date-specific result, though the same cannot be said for the United States.

# %% [markdown]
# Robustness test 4
# Endogenous Break detection.
# tests regression three.
# Removes any input into determing dates that may have resulted in significant energy shocks in the economy. The data is then serached monthly for a date that produces the lowest combined residual sum of sqaures acrss the sub-peridos (months). Uisng thus other breaks were identiifed within the the data.
# This shows that the 2022 shock is not the most significant shock in the data, although it is still notable.

# %% [markdown]
# Robustness test 5
# COVID exclusion.
# Tests regression three.
# Covid provided supply chain disruptions that influenced core inflation that was not correlated with energy price trnasmission and therefore theere is a risk that this is represented in the 2022 data, distrotingt the results. Two tests were then run, one in which the regressions include a dummy variable that represents January 2022 to December 2023. The second test ustilises a seperate covid dummy variable to parttion the two time periods explicitly.
# Canada and the United Kingodm are fine with a strongly significant result in the prure 2002 window with nio covid effects. The United Kingodm has a seperate Covid-repsonse distinct from the 2022 energy shiock that is quite large and is significant. The United States is significant at the 5% level only during the second test where covid is partiitoned out. This shows that the Unoted States break coeeficent in the regressions has some contamination with the covid period and is not entirely relevant towards the 2022 price shock.

# %% [markdown]
# Robustness test 6.
# Gas price check (US only)
# Given that the 2022 price shock derives primarily form the increased in LNG prices this test checks whether using the gas pri

# %% [markdown]
# Robs=ustness test 7
# Tests regressions one and three.
# Reruns the regressions using the month on month changes in each series rather than ptuerly the level of core CPI on the energy CPI, thus removing the trneding compmonent and making the series stationary (addressing issues in test 2) so thatn any relationship is an actual short-run interation rather than just two variabels tgat share a common trend.
# The strucutral break is no longer present for Canada and the United Kingdom. Uisng the in unision with the results in the second robustness test it hsows thta the results captuare a long rin co-trending relationship, with core and energy CPI moving together over time. But the 2022 strucutral shift is a persistent break rather than a change in short-run month to month dynamics. The United States strucutural break is robust  and is signifcanr to 1% but is negative. This shows that in the United State the short-run dynamic chnaged, with energy prices dampening in the monthly rate of energy price movemenets.

# %% [markdown]
# Robustness test 8
# Alternative lenghts of the lags
# Tests regression two.
# In the second regression their is 12 lags for energy CPI to allow for a reasonable amount of time for energy prices to trans,it into core CPI. This test changes the amount of lags from 12 to 6 and 24, giving comapriso to a six month and two year period.
# All three countries have a cumulative pass through that is efectively zero at all of the different lag lengths, shwoing that once core inflation momentum is accounted for therefore this is regression (regression 2) is fully robust.

# %% [markdown]
# Robustness test 9
# Controlling for the Brent Crude oil price.
# Tests regression one.
# Adding a control for the Brent Crude Oil price to determine if the changes in eneergy CPI are just. aproxy for the changes in the Brent Crude Oil price and not capturing country-specific transamission mechanisms. A signifcant Brent Crude Oil result would essentially sate that the only fator in the energy CPI is the price of oil and not the energy generation methds for each country.
# The Brent Crude variable is not siginicant for any of the countries, thus showing that the changes in each nations energy markets are not enrirely due to the chnage oin the price of oil.

# %% [markdown]
# Robustness test 10
# Two way fixed effects
# Tests regression four.
# Testing if the residuals are correlated across the countries after teh mdoel estimation in the frourth regression where all three countries are o=pooled togehter. If the errrors tned to be similar amongt the countries (i.e. negative or positve at the same time) to see if they're is a common shock they're simulatanoeusly exposed to that isnt in that particular model. WIthh all three countreis exposed to the 2022 shock, this would be expeceted and show that the 2022 enegy shock effects all three countries.
# There is strong cross-setional dependecne that is significant indicating that the 2022 shock is definitely affwcting all three nations, although this doesnt give great results as to what degree it effects eacxh.
